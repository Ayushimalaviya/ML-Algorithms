# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.inspection import permutation_importance
from sklearn.metrics import confusion_matrix
#for multiple feature Gaussian is better to use
from sklearn.naive_bayes import GaussianNB
import pandas as pd

# %%
data = pd.read_csv('breast-cancer-wisconsin.csv', na_values = '?')
data1 = data.dropna()
data1
# Out:
#       Sample  F1  F2  F3  F4  F5    F6  F7  F8  F9  Class
# 0    1000025   5   1   1   1   2   1.0   3   1   1      2
# 1    1002945   5   4   4   5   7  10.0   3   2   1      2
# 2    1015425   3   1   1   1   2   2.0   3   1   1      2
# 3    1016277   6   8   8   1   3   4.0   3   7   1      2
# 4    1017023   4   1   1   3   2   1.0   3   1   1      2
# ..       ...  ..  ..  ..  ..  ..   ...  ..  ..  ..    ...
# 694   776715   3   1   1   1   3   2.0   1   1   1      2
# 695   841769   2   1   1   1   2   1.0   1   1   1      2
# 696   888820   5  10  10   3   7   3.0   8  10   2      4
# 697   897471   4   8   6   4   3   4.0  10   6   1      4
# 698   897471   4   8   8   5   4   5.0  10   4   1      4
#
# [683 rows x 11 columns]

# %%
X = data1.iloc[:,1:10]
y = data1.iloc[:,10]
X_test, X_train,Y_test,Y_train = train_test_split(X, y, test_size = 0.3)

# %%
#created classifier
GNB = GaussianNB()
#fit the model using train datasets
GNB.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
# to predict the class for test data set
y_pred = GNB.predict(X_test)

# %%
y_test = Y_test.tolist()
x_test = pd.DataFrame(X_test)
x_test['Class'] = y_test
x_test['Predicted_class'] = y_pred
print(x_test.head(20))
# Out:
#      F1  F2  F3  F4  F5    F6  F7  F8  F9  Class  Predicted_class
# 423   5   1   3   1   2   1.0   2   1   1      2                2
# 698   4   8   8   5   4   5.0  10   4   1      4                4
# 121   4   2   1   1   2   2.0   3   1   1      2                2
# 215   8   7   8   7   5   5.0   5  10   2      4                4
# 81    4   1   1   2   2   1.0   2   1   1      2                2
# 206  10  10   9   3   7   5.0   3   5   1      4                4
# 94    2   1   1   1   2   1.0   3   1   1      2                2
# 267   3   3   5   2   3  10.0   7   1   1      4                4
# 90    1   1   1   1   2   1.0   3   1   1      2                2
# 354   1   1   1   1   2   1.0   2   1   1      2                2
# 568   8   4   4   1   6  10.0   2   5   2      4                4
# 351   2   1   1   1   2   1.0   3   1   1      2                2
# 156   1   2   2   1   2   1.0   2   1   1      2                2
# ...

# %%
target = ['Benign', 'Malignant']
print('Accuracy Score is: ',accuracy_score(y_test, y_pred)) #TP+FN/TP+TF+FP+FN
print('\n\n\nclassification_report of data after Knn applied: \n',classification_report(y_test, y_pred,target_names=target),'\n\n') 
#precision = TP/TP+FP & recall = TP/TP+TN & f1_score = harmonic_mean of pre and recall 
print('Confusion Matrix of data predicted \n',confusion_matrix(y_test, y_pred),'\n\n') #TP,TN,FP,FN,
print('The model with benign class has good precision(exactness) and recall(completeness) value along with high f1-score.')
# Out:
# Accuracy Score is:  0.9686192468619247
#
#
#
# classification_report of data after Knn applied:
#                precision    recall  f1-score   support
#
#       Benign       0.98      0.97      0.98       325
#    Malignant       0.94      0.97      0.95       153
#
#     accuracy                           0.97       478
#    macro avg       0.96      0.97      0.96       478
# weighted avg       0.97      0.97      0.97       478
#
#
#
# Confusion Matrix of data predicted
#  [[315  10]
#  [  5 148]]
#
#
# The model with benign class has good precision(exactness) and recall(completeness) value along with high f1-score.
